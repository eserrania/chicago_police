# %% [markdown]
# #  Project Progress Report
# ## Andres Nigenda, Elias Serrania, Krista Chan

# %%
# %load_ext autoreload
# %autoreload 2

import read_data as rd
import train_test as tt
import ml_loop as ml
import pandas as pd
import numpy as np
import full_pipeline as fp

# %%
raw_dfs = fp.RawDfs()

# %%
set_list = raw_dfs.create_train_tests(np.timedelta64(1,'Y'))
# Out:
# Allegation sets
#
# Training set 0 is trained from 2010-01-01 to 2010-12-31 to predict the outcome from 2011-01-01 to 2012-01-01 and tested on outcomes in 2012-01-02 to 2013-01-01
#
# Training set 1 is trained from 2010-01-01 to 2011-12-31 to predict the outcome from 2012-01-01 to 2012-12-31 and tested on outcomes in 2013-01-01 to 2014-01-01
#
# Training set 2 is trained from 2010-01-01 to 2012-12-30 to predict the outcome from 2012-12-31 to 2013-12-31 and tested on outcomes in 2014-01-01 to 2015-01-02
#
# Training set 3 is trained from 2010-01-01 to 2013-12-30 to predict the outcome from 2013-12-31 to 2015-01-01 and tested on outcomes in 2015-01-02 to 2016-01-02
#
# Training set 4 is trained from 2010-01-01 to 2014-12-31 to predict the outcome from 2015-01-01 to 2016-01-01 and tested on outcomes in 2016-01-02 to 2017-01-01
#
# Training set 5 is trained from 2010-01-01 to 2015-12-31 to predict the outcome from 2016-01-01 to 2016-12-31 and tested on outcomes in 2017-01-01 to 2018-01-01
#
#
#
# TRR sets
#
# Training set 0 is trained from 2010-01-01 to 2010-12-31 to predict the outcome from 2011-01-01 to 2012-01-01 and tested on outcomes in 2012-01-02 to 2013-01-01
#
# Training set 1 is trained from 2010-01-01 to 2011-12-31 to predict the outcome from 2012-01-01 to 2012-12-31 and tested on outcomes in 2013-01-01 to 2014-01-01
#
# Training set 2 is trained from 2010-01-01 to 2012-12-30 to predict the outcome from 2012-12-31 to 2013-12-31 and tested on outcomes in 2014-01-01 to 2015-01-02
#
# Training set 3 is trained from 2010-01-01 to 2013-12-30 to predict the outcome from 2013-12-31 to 2015-01-01 and tested on outcomes in 2015-01-02 to 2016-01-02
#
#
#
# Salary sets
# Training set 0 is trained from 2010-01-01 to 2010-12-31 to predict the outcome from 2011-01-01 to 2012-01-01 and tested on outcomes in 2012-01-02 to 2013-01-01
#
# Training set 1 is trained from 2010-01-01 to 2011-12-31 to predict the outcome from 2012-01-01 to 2012-12-31 and tested on outcomes in 2013-01-01 to 2014-01-01
#
# Training set 2 is trained from 2010-01-01 to 2012-12-30 to predict the outcome from 2012-12-31 to 2013-12-31 and tested on outcomes in 2014-01-01 to 2015-01-02
#
# Training set 3 is trained from 2010-01-01 to 2013-12-30 to predict the outcome from 2013-12-31 to 2015-01-01 and tested on outcomes in 2015-01-02 to 2016-01-02

# %%
for test_set in set_list:
    test_set.add_train_features()
    test_set.add_test_features()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train
# firearm_used
# False    4574
# True      198
# Name: officer_id, dtype: int64
# used_firearm
# 0    13717
# 1      101
# Name: id, dtype: int64
# firearm_outcome
# 0    13716
# 1      102
# Name: id, dtype: int64
#
# final_finding
# EX     556
# NS    2325
# SU     621
# UN    1395
# ZZ       5
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    13471
# 1      347
# Name: id, dtype: int64
#
# Test
# firearm_used
# False    5552
# True      279
# Name: officer_id, dtype: int64
# used_firearm
# 0    2825
# 1       5
# Name: id, dtype: int64
# firearm_outcome
# 0    2822
# 1       8
# Name: id, dtype: int64
#
# final_finding
# EX     719
# NS    2868
# SU     896
# UN    1917
# ZZ       6
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    2686
# 1     144
# Name: id, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train
# firearm_used
# False    5548
# True      279
# Name: officer_id, dtype: int64
# used_firearm
# 0    13673
# 1      197
# Name: id, dtype: int64
# firearm_outcome
# 0    13778
# 1       92
# Name: id, dtype: int64
#
# final_finding
# EX     718
# NS    2868
# SU     894
# UN    1915
# ZZ       6
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    13550
# 1      320
# Name: id, dtype: int64
#
# Test
# firearm_used
# False    6396
# True      339
# Name: officer_id, dtype: int64
# used_firearm
# 0    2168
# 1       9
# Name: id, dtype: int64
# firearm_outcome
# 0    2175
# 1       2
# Name: id, dtype: int64
#
# final_finding
# EX     918
# NS    3265
# SU    1221
# UN    2348
# ZZ       7
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    2055
# 1     122
# Name: id, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train
# firearm_used
# False    6389
# True      338
# Name: officer_id, dtype: int64
# used_firearm
# 0    14039
# 1      279
# Name: id, dtype: int64
# firearm_outcome
# 0    14251
# 1       67
# Name: id, dtype: int64
#
# final_finding
# EX     912
# NS    3264
# SU    1221
# UN    2345
# ZZ       7
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    13928
# 1      390
# Name: id, dtype: int64
#
# Test
# firearm_used
# False    7198
# True      396
# Name: officer_id, dtype: int64
# used_firearm
# 0    1916
# 1      10
# Name: id, dtype: int64
# firearm_outcome
# 0    1925
# 1       1
# Name: id, dtype: int64
#
# final_finding
# EX    1097
# NS    3604
# SU    1437
# UN    2687
# ZZ       9
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    1821
# 1     105
# Name: id, dtype: int64
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train
# firearm_used
# False    7198
# True      396
# Name: officer_id, dtype: int64
# used_firearm
# 0    14566
# 1      338
# Name: id, dtype: int64
# firearm_outcome
# 0    14830
# 1       74
# Name: id, dtype: int64
#
# final_finding
# EX    1097
# NS    3603
# SU    1437
# UN    2687
# ZZ       9
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    14634
# 1      270
# Name: id, dtype: int64
#
# Test
# firearm_used
# False    7774
# True      446
# Name: officer_id, dtype: int64
# used_firearm
# 0    1494
# 1       9
# Name: id, dtype: int64
# firearm_outcome
# 0    1502
# 1       1
# Name: id, dtype: int64
#
# final_finding
# EX    1195
# NS    3862
# SU    1611
# UN    2933
# ZZ      17
# Name: officer_id, dtype: int64
# sustained_outcome
# 0    1440
# 1      63
# Name: id, dtype: int64

# %%
# Model parameters
GRID = 'all'
CLFRS_TO_RUN = ['RandomForest',
                'ExtraTrees',
                'AdaBoost',
                'DecisionTree',
                'GradientBoosting',
                'Bagging',
                'LogisticRegression']
label_lst = ['sustained_outcome', 'firearm_outcome']

# Metrics and thresholds
METRIC_DICT = {'precision': [100, 5, 20, 50, 80],
               'recall': [100, 5, 20, 50, 80],
               'f1': [5],
               'accuracy': [50]}
METRICS = 'pop'

# %%
for i in range(0, 4):
    set_list[i].reg_features.remove('unit_id_nan')
for i in range(0, 4):
    set_list[i].train = set_list[i].train.fillna(set_list[i].train.mean())
for i in range(0, 4):
    set_list[i].test = set_list[i].test.fillna(set_list[i].test.mean())
for i in range(0, 4):
    set_list[i].train = set_list[i].train.fillna(0)
for i in range(0, 4):
    set_list[i].test = set_list[i].test.fillna(0)
for i in range(0, 4):
    set_list[i].aug_features.remove('unit_id_nan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-bdd48b3e939d> in <module>
#       1 for i in range(0, 4):
# ----> 2     set_list[i].reg_features.remove('unit_id_nan')
#       3 for i in range(0, 4):
#       4     set_list[i].train = set_list[i].train.fillna(set_list[i].train.mean())
#       5 for i in range(0, 4):
#
# ValueError: list.remove(x): x not in list

# %%
res_df2 = ml.classifier_loop(set_list, GRID, CLFRS_TO_RUN, METRIC_DICT, label_lst,
                             METRICS, "big_loop_output.csv", plot=False)
# Out:
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 500, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 100, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 10, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** augmented model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome sustained_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** network model on outcome firearm_outcome, TrainTest object 0
# * Working on the RandomForest classifier with parameters {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 500, 'n_estimators': 20, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2010-12-31 05:49:12 and testing from 2012-01-02 11:38:24 to 2013-01-01 17:27:36.
# ** regular model on outcome sustained_outcome, TrainTest object 0
# ...
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the Bagging classifier with parameters {'bootstrap': False, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 1, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 10, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l2', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** regular model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# ** augmented model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** augmented model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome sustained_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# ** network model on outcome firearm_outcome, TrainTest object 3
# * Working on the LogisticRegression classifier with parameters {'Cs': 50, 'penalty': 'l1', 'random_state': 84, 'solver': 'liblinear'}.
# * Training from 2010-01-01 00:00:00 to 2013-12-30 23:16:48 and testing from 2015-01-02 05:06:00 to 2016-01-02 10:55:12.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
res_df2.head()
# Out:
#           model                                        importances param_set  \
# 0  RandomForest  [0.006474066237635299, 0.04808159560651084, 0....         0
# 1  RandomForest  [0.01208353117417826, 0.10465812442110456, 0.0...         0
# 2  RandomForest  [0.000247726748259135, 0.02758105864007223, 0....         0
# 3  RandomForest  [0.0010018081152277593, 0.03041916061172741, 0...         0
# 4  RandomForest  [0.00029854178211476573, 5.417585104451877e-06...         0
#
#                                           parameters set       type  \
# 0  {'criterion': 'gini', 'max_depth': 5, 'min_sam...   0    regular
# 1  {'criterion': 'gini', 'max_depth': 5, 'min_sam...   0    regular
# 2  {'criterion': 'gini', 'max_depth': 5, 'min_sam...   0  augmented
# 3  {'criterion': 'gini', 'max_depth': 5, 'min_sam...   0  augmented
# 4  {'criterion': 'gini', 'max_depth': 5, 'min_sam...   0    network
#
#              outcome train_start           train_end          test_start  ...  \
# 0  sustained_outcome  2010-01-01 2010-12-31 05:49:12 2012-01-02 11:38:24  ...
# 1    firearm_outcome  2010-01-01 2010-12-31 05:49:12 2012-01-02 11:38:24  ...
# 2  sustained_outcome  2010-01-01 2010-12-31 05:49:12 2012-01-02 11:38:24  ...
# 3    firearm_outcome  2010-01-01 2010-12-31 05:49:12 2012-01-02 11:38:24  ...
# 4  sustained_outcome  2010-01-01 2010-12-31 05:49:12 2012-01-02 11:38:24  ...
#
#   precision_at_20  precision_at_50  precision_at_80  recall_at_100  \
# 0        0.104240         0.068551         0.057862            1.0
# 1        0.008834         0.004947         0.003534            1.0
# 2        0.113074         0.071378         0.057862            1.0
# 3        0.008834         0.004947         0.003534            1.0
# 4        0.098940         0.075618         0.059629            1.0
#
#    recall_at_5  recall_at_20  recall_at_50  recall_at_80   f1_at_5  \
# 0     0.173611      0.409722      0.673611      0.909722  0.175439
# 1     0.500000      0.625000      0.875000      1.000000  0.053691
# 2     0.270833      0.444444      0.701389      0.909722  0.273684
# 3     0.500000      0.625000      0.875000      1.000000  0.053691
# 4     0.298611      0.388889      0.743056      0.937500  0.301754
#
#    accuracy_at_50
# 0        0.517668
# 1        0.502120
# 2        0.520495
# 3        0.502120
# 4        0.524735
#
# [5 rows x 23 columns]

# %%
# Libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# look at types of outcome and models, max
pd.set_option('display.max_rows', 500)
best_cs = pd.pivot_table(res_df2, index=['set', 'outcome','type', 'model'], aggfunc='max')
best_cs.sort_values(by=['set', 'outcome', 'precision_at_5'], ascending=False)
# Out:
#                                                     accuracy_at_50   f1_at_5  \
# set outcome           type      model
# 3   sustained_outcome augmented RandomForest              0.535595  0.579710
#                                 Bagging                   0.530273  0.565217
#                                 GradientBoosting          0.534265  0.507246
#                       regular   Bagging                   0.531603  0.507246
#                                 RandomForest              0.532934  0.492754
#                                 GradientBoosting          0.532934  0.376812
#                       augmented ExtraTrees                0.526281  0.362319
#                                 AdaBoost                  0.528942  0.304348
#                       network   GradientBoosting          0.522289  0.304348
#                       augmented DecisionTree              0.524950  0.289855
#                       network   ExtraTrees                0.518297  0.289855
#                                 RandomForest              0.526281  0.289855
#                                 AdaBoost                  0.522289  0.275362
#                                 Bagging                   0.524950  0.275362
#                       regular   ExtraTrees                0.524950  0.275362
#                       network   DecisionTree              0.518297  0.260870
#                       regular   DecisionTree              0.522289  0.188406
#                                 AdaBoost                  0.527611  0.173913
#                       network   LogisticRegression        0.510313  0.130435
#                       augmented LogisticRegression        0.510313  0.043478
#                       regular   LogisticRegression        0.510313  0.028986
#     firearm_outcome   augmented AdaBoost                  0.500998  0.026316
#                                 Bagging                   0.500998  0.026316
#                                 DecisionTree              0.500998  0.026316
#                                 GradientBoosting          0.500998  0.026316
#                                 RandomForest              0.500998  0.026316
#                       network   DecisionTree              0.500998  0.026316
#                                 GradientBoosting          0.500998  0.026316
#                       regular   AdaBoost                  0.500998  0.026316
#                                 Bagging                   0.500998  0.026316
#                                 DecisionTree              0.500998  0.026316
#                                 GradientBoosting          0.500998  0.026316
#                                 RandomForest              0.500998  0.026316
#                       augmented ExtraTrees                0.500998  0.000000
#                                 LogisticRegression        0.500998  0.000000
#                       network   AdaBoost                  0.500998  0.000000
#                                 Bagging                   0.499667  0.000000
#                                 ExtraTrees                0.500998  0.000000
#                                 LogisticRegression        0.500998  0.000000
#                                 RandomForest              0.500998  0.000000
#                       regular   ExtraTrees                0.500998  0.000000
#                                 LogisticRegression        0.500998  0.000000
# 2   sustained_outcome augmented Bagging                   0.537902  0.537313
#                                 RandomForest              0.541018  0.537313
#                       regular   Bagging                   0.535826  0.447761
#                       augmented GradientBoosting          0.541018  0.437811
#                       regular   RandomForest              0.538941  0.437811
#                                 GradientBoosting          0.535826  0.378109
#                       network   RandomForest              0.532710  0.338308
#                       augmented DecisionTree              0.535826  0.318408
#                                 ExtraTrees                0.531672  0.318408
#                       network   AdaBoost                  0.529595  0.318408
#                                 GradientBoosting          0.532710  0.318408
#                                 Bagging                   0.532710  0.308458
#                                 DecisionTree              0.528557  0.298507
#                                 ExtraTrees                0.526480  0.298507
#                       augmented AdaBoost                  0.536864  0.268657
#                       regular   ExtraTrees                0.534787  0.238806
#                                 DecisionTree              0.532710  0.189055
#                                 AdaBoost                  0.533749  0.179104
#                       network   LogisticRegression        0.525441  0.159204
#                       augmented LogisticRegression        0.525441  0.079602
#                       regular   LogisticRegression        0.525441  0.039801
#     firearm_outcome   augmented AdaBoost                  0.500519  0.020619
#                                 Bagging                   0.500519  0.020619
#                                 DecisionTree              0.500519  0.020619
#                                 ExtraTrees                0.500519  0.020619
#                                 GradientBoosting          0.500519  0.020619
#                                 RandomForest              0.500519  0.020619
#                       network   DecisionTree              0.500519  0.020619
#                                 ExtraTrees                0.500519  0.020619
#                                 GradientBoosting          0.500519  0.020619
#                       regular   AdaBoost                  0.500519  0.020619
#                                 Bagging                   0.500519  0.020619
#                                 DecisionTree              0.500519  0.020619
#                                 ExtraTrees                0.500519  0.020619
#                                 GradientBoosting          0.500519  0.020619
#                                 RandomForest              0.500519  0.020619
#                       augmented LogisticRegression        0.500519  0.000000
#                       network   AdaBoost                  0.500519  0.000000
#                                 Bagging                   0.499481  0.000000
#                                 LogisticRegression        0.500519  0.000000
#                                 RandomForest              0.500519  0.000000
#                       regular   LogisticRegression        0.500519  0.000000
# 1   sustained_outcome augmented RandomForest              0.536059  0.486957
#                                 Bagging                   0.538815  0.478261
#                       regular   RandomForest              0.535140  0.434783
#                                 Bagging                   0.537896  0.426087
#                       augmented GradientBoosting          0.535140  0.400000
#                       regular   GradientBoosting          0.533303  0.339130
#                       augmented AdaBoost                  0.532384  0.321739
#                       network   RandomForest              0.536977  0.295652
#                                 GradientBoosting          0.537896  0.286957
#                       augmented DecisionTree              0.536977  0.278261
#                       network   Bagging                   0.537896  0.278261
#                                 ExtraTrees                0.533303  0.260870
#                                 AdaBoost                  0.534221  0.252174
#                                 DecisionTree              0.535140  0.252174
#                       regular   AdaBoost                  0.535140  0.234783
#                       augmented ExtraTrees                0.526872  0.226087
#                       regular   ExtraTrees                0.527791  0.226087
#                                 DecisionTree              0.527791  0.217391
#                       augmented LogisticRegression        0.532384  0.191304
#                       network   LogisticRegression        0.532384  0.139130
#                       regular   LogisticRegression        0.532384  0.052174
#     firearm_outcome   augmented AdaBoost                  0.501148  0.036364
#                                 Bagging                   0.501148  0.036364
#                                 DecisionTree              0.501148  0.036364
#                                 ExtraTrees                0.501148  0.036364
#                                 GradientBoosting          0.501148  0.036364
#                                 RandomForest              0.501148  0.036364
#                       regular   AdaBoost                  0.501148  0.036364
#                                 Bagging                   0.501148  0.036364
#                                 DecisionTree              0.501148  0.036364
#                                 ExtraTrees                0.501148  0.036364
#                                 GradientBoosting          0.501148  0.036364
#                                 RandomForest              0.501148  0.036364
#                                 LogisticRegression        0.500230  0.018182
#                       augmented LogisticRegression        0.500230  0.000000
#                       network   AdaBoost                  0.500230  0.000000
#                                 Bagging                   0.500230  0.000000
#                                 DecisionTree              0.500230  0.000000
#                                 ExtraTrees                0.500230  0.000000
#                                 GradientBoosting          0.501148  0.000000
#                                 LogisticRegression        0.500230  0.000000
#                                 RandomForest              0.500230  0.000000
# 0   sustained_outcome augmented RandomForest              0.533216  0.449123
#                                 GradientBoosting          0.530389  0.435088
#                       regular   RandomForest              0.529682  0.428070
#                       augmented Bagging                   0.531802  0.414035
#                       regular   Bagging                   0.531802  0.371930
#                       augmented ExtraTrees                0.523322  0.343860
#                       regular   GradientBoosting          0.526855  0.322807
#                       augmented DecisionTree              0.531095  0.308772
#                       network   Bagging                   0.525442  0.301754
#                                 RandomForest              0.526148  0.301754
#                       augmented AdaBoost                  0.525442  0.294737
#                       network   GradientBoosting          0.526148  0.294737
#                                 AdaBoost                  0.525442  0.287719
#                                 DecisionTree              0.526148  0.287719
#                                 ExtraTrees                0.525442  0.287719
#                                 LogisticRegression        0.523322  0.252632
#                       regular   DecisionTree              0.523322  0.252632
#                                 AdaBoost                  0.524028  0.231579
#                                 ExtraTrees                0.525442  0.217544
#                       augmented LogisticRegression        0.521908  0.189474
#                       regular   LogisticRegression        0.516961  0.021053
#     firearm_outcome   augmented AdaBoost                  0.502120  0.080537
#                                 Bagging                   0.501413  0.080537
#                                 ExtraTrees                0.502827  0.080537
#                                 GradientBoosting          0.502827  0.080537
#                                 RandomForest              0.502827  0.080537
#                       regular   RandomForest              0.502827  0.080537
#                       augmented DecisionTree              0.502827  0.067114
#                       regular   AdaBoost                  0.502120  0.067114
#                                 Bagging                   0.501413  0.067114
#                                 DecisionTree              0.502827  0.067114
#                                 ExtraTrees                0.502120  0.067114
#                                 GradientBoosting          0.502827  0.067114
#                       network   AdaBoost                  0.500707  0.040268
#                                 Bagging                   0.500707  0.040268
#                                 RandomForest              0.500707  0.040268
#                                 DecisionTree              0.500707  0.026846
#                                 ExtraTrees                0.500707  0.026846
#                                 GradientBoosting          0.500707  0.026846
#                       regular   LogisticRegression        0.500707  0.026846
#                       augmented LogisticRegression        0.500707  0.013423
#                       network   LogisticRegression        0.500707  0.013423
#
#                                                     param_set  \
# set outcome           type      model
# 3   sustained_outcome augmented RandomForest               71
#                                 Bagging                    11
#                                 GradientBoosting           53
#                       regular   Bagging                    11
#                                 RandomForest               71
#                                 GradientBoosting           53
#                       augmented ExtraTrees                  5
#                                 AdaBoost                    8
#                       network   GradientBoosting           53
#                       augmented DecisionTree               35
#                       network   ExtraTrees                  5
#                                 RandomForest               71
#                                 AdaBoost                    8
#                                 Bagging                    11
#                       regular   ExtraTrees                  5
#                       network   DecisionTree               35
#                       regular   DecisionTree               35
#                                 AdaBoost                    8
#                       network   LogisticRegression          5
#                       augmented LogisticRegression          5
#                       regular   LogisticRegression          5
#     firearm_outcome   augmented AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       network   DecisionTree               35
#                                 GradientBoosting           53
#                       regular   AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       augmented ExtraTrees                  5
#                                 LogisticRegression          5
#                       network   AdaBoost                    8
#                                 Bagging                    11
#                                 ExtraTrees                  5
#                                 LogisticRegression          5
#                                 RandomForest               71
#                       regular   ExtraTrees                  5
#                                 LogisticRegression          5
# 2   sustained_outcome augmented Bagging                    11
#                                 RandomForest               71
#                       regular   Bagging                    11
#                       augmented GradientBoosting           53
#                       regular   RandomForest               71
#                                 GradientBoosting           53
#                       network   RandomForest               71
#                       augmented DecisionTree               35
#                                 ExtraTrees                  5
#                       network   AdaBoost                    8
#                                 GradientBoosting           53
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                       augmented AdaBoost                    8
#                       regular   ExtraTrees                  5
#                                 DecisionTree               35
#                                 AdaBoost                    8
#                       network   LogisticRegression          5
#                       augmented LogisticRegression          5
#                       regular   LogisticRegression          5
#     firearm_outcome   augmented AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       network   DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                       regular   AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       augmented LogisticRegression          5
#                       network   AdaBoost                    8
#                                 Bagging                    11
#                                 LogisticRegression          5
#                                 RandomForest               71
#                       regular   LogisticRegression          5
# 1   sustained_outcome augmented RandomForest               71
#                                 Bagging                    11
#                       regular   RandomForest               71
#                                 Bagging                    11
#                       augmented GradientBoosting           53
#                       regular   GradientBoosting           53
#                       augmented AdaBoost                    8
#                       network   RandomForest               71
#                                 GradientBoosting           53
#                       augmented DecisionTree               35
#                       network   Bagging                    11
#                                 ExtraTrees                  5
#                                 AdaBoost                    8
#                                 DecisionTree               35
#                       regular   AdaBoost                    8
#                       augmented ExtraTrees                  5
#                       regular   ExtraTrees                  5
#                                 DecisionTree               35
#                       augmented LogisticRegression          5
#                       network   LogisticRegression          5
#                       regular   LogisticRegression          5
#     firearm_outcome   augmented AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       regular   AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 RandomForest               71
#                                 LogisticRegression          5
#                       augmented LogisticRegression          5
#                       network   AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 LogisticRegression          5
#                                 RandomForest               71
# 0   sustained_outcome augmented RandomForest               71
#                                 GradientBoosting           53
#                       regular   RandomForest               71
#                       augmented Bagging                    11
#                       regular   Bagging                    11
#                       augmented ExtraTrees                  5
#                       regular   GradientBoosting           53
#                       augmented DecisionTree               35
#                       network   Bagging                    11
#                                 RandomForest               71
#                       augmented AdaBoost                    8
#                       network   GradientBoosting           53
#                                 AdaBoost                    8
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 LogisticRegression          5
#                       regular   DecisionTree               35
#                                 AdaBoost                    8
#                                 ExtraTrees                  5
#                       augmented LogisticRegression          5
#                       regular   LogisticRegression          5
#     firearm_outcome   augmented AdaBoost                    8
#                                 Bagging                    11
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                                 RandomForest               71
#                       regular   RandomForest               71
#                       augmented DecisionTree               35
#                       regular   AdaBoost                    8
#                                 Bagging                    11
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                       network   AdaBoost                    8
#                                 Bagging                    11
#                                 RandomForest               71
#                                 DecisionTree               35
#                                 ExtraTrees                  5
#                                 GradientBoosting           53
#                       regular   LogisticRegression          5
#                       augmented LogisticRegression          5
#                       network   LogisticRegression          5
#
#                                                     precision_at_100  \
# set outcome           type      model
# 3   sustained_outcome augmented RandomForest                0.041916
#                                 Bagging                     0.041916
#                                 GradientBoosting            0.041916
#                       regular   Bagging                     0.041916
#                                 RandomForest                0.041916
#                                 GradientBoosting            0.041916
#                       augmented ExtraTrees                  0.041916
#                                 AdaBoost                    0.041916
#                       network   GradientBoosting            0.041916
#                       augmented DecisionTree                0.041916
#                       network   ExtraTrees                  0.041916
#                                 RandomForest                0.041916
#                                 AdaBoost                    0.041916
#                                 Bagging                     0.041916
#                       regular   ExtraTrees                  0.041916
#                       network   DecisionTree                0.041916
#                       regular   DecisionTree                0.041916
#                                 AdaBoost                    0.041916
#                       network   LogisticRegression          0.041916
#                       augmented LogisticRegression          0.041916
#                       regular   LogisticRegression          0.041916
#     firearm_outcome   augmented AdaBoost                    0.000665
#                                 Bagging                     0.000665
#                                 DecisionTree                0.000665
#                                 GradientBoosting            0.000665
#                                 RandomForest                0.000665
#                       network   DecisionTree                0.000665
#                                 GradientBoosting            0.000665
#                       regular   AdaBoost                    0.000665
#                                 Bagging                     0.000665
#                                 DecisionTree                0.000665
#                                 GradientBoosting            0.000665
#                                 RandomForest                0.000665
#                       augmented ExtraTrees                  0.000665
#                                 LogisticRegression          0.000665
#                       network   AdaBoost                    0.000665
#                                 Bagging                     0.000665
#                                 ExtraTrees                  0.000665
#                                 LogisticRegression          0.000665
#                                 RandomForest                0.000665
#                       regular   ExtraTrees                  0.000665
#                                 LogisticRegression          0.000665
# 2   sustained_outcome augmented Bagging                     0.054517
#                                 RandomForest                0.054517
#                       regular   Bagging                     0.054517
#                       augmented GradientBoosting            0.054517
#                       regular   RandomForest                0.054517
#                                 GradientBoosting            0.054517
#                       network   RandomForest                0.054517
#                       augmented DecisionTree                0.054517
#                                 ExtraTrees                  0.054517
#                       network   AdaBoost                    0.054517
#                                 GradientBoosting            0.054517
#                                 Bagging                     0.054517
#                                 DecisionTree                0.054517
#                                 ExtraTrees                  0.054517
#                       augmented AdaBoost                    0.054517
#                       regular   ExtraTrees                  0.054517
#                                 DecisionTree                0.054517
#                                 AdaBoost                    0.054517
#                       network   LogisticRegression          0.054517
#                       augmented LogisticRegression          0.054517
#                       regular   LogisticRegression          0.054517
#     firearm_outcome   augmented AdaBoost                    0.000519
#                                 Bagging                     0.000519
#                                 DecisionTree                0.000519
#                                 ExtraTrees                  0.000519
#                                 GradientBoosting            0.000519
#                                 RandomForest                0.000519
#                       network   DecisionTree                0.000519
#                                 ExtraTrees                  0.000519
#                                 GradientBoosting            0.000519
#                       regular   AdaBoost                    0.000519
#                                 Bagging                     0.000519
#                                 DecisionTree                0.000519
#                                 ExtraTrees                  0.000519
#                                 GradientBoosting            0.000519
#                                 RandomForest                0.000519
#                       augmented LogisticRegression          0.000519
#                       network   AdaBoost                    0.000519
#                                 Bagging                     0.000519
#                                 LogisticRegression          0.000519
#                                 RandomForest                0.000519
#                       regular   LogisticRegression          0.000519
# 1   sustained_outcome augmented RandomForest                0.056040
#                                 Bagging                     0.056040
#                       regular   RandomForest                0.056040
#                                 Bagging                     0.056040
#                       augmented GradientBoosting            0.056040
#                       regular   GradientBoosting            0.056040
#                       augmented AdaBoost                    0.056040
#                       network   RandomForest                0.056040
#                                 GradientBoosting            0.056040
#                       augmented DecisionTree                0.056040
#                       network   Bagging                     0.056040
#                                 ExtraTrees                  0.056040
#                                 AdaBoost                    0.056040
#                                 DecisionTree                0.056040
#                       regular   AdaBoost                    0.056040
#                       augmented ExtraTrees                  0.056040
#                       regular   ExtraTrees                  0.056040
#                                 DecisionTree                0.056040
#                       augmented LogisticRegression          0.056040
#                       network   LogisticRegression          0.056040
#                       regular   LogisticRegression          0.056040
#     firearm_outcome   augmented AdaBoost                    0.000919
#                                 Bagging                     0.000919
#                                 DecisionTree                0.000919
#                                 ExtraTrees                  0.000919
#                                 GradientBoosting            0.000919
#                                 RandomForest                0.000919
#                       regular   AdaBoost                    0.000919
#                                 Bagging                     0.000919
#                                 DecisionTree                0.000919
#                                 ExtraTrees                  0.000919
#                                 GradientBoosting            0.000919
#                                 RandomForest                0.000919
#                                 LogisticRegression          0.000919
#                       augmented LogisticRegression          0.000919
#                       network   AdaBoost                    0.000919
#                                 Bagging                     0.000919
#                                 DecisionTree                0.000919
#                                 ExtraTrees                  0.000919
#                                 GradientBoosting            0.000919
#                                 LogisticRegression          0.000919
#                                 RandomForest                0.000919
# 0   sustained_outcome augmented RandomForest                0.050883
#                                 GradientBoosting            0.050883
#                       regular   RandomForest                0.050883
#                       augmented Bagging                     0.050883
#                       regular   Bagging                     0.050883
#                       augmented ExtraTrees                  0.050883
#                       regular   GradientBoosting            0.050883
#                       augmented DecisionTree                0.050883
#                       network   Bagging                     0.050883
#                                 RandomForest                0.050883
#                       augmented AdaBoost                    0.050883
#                       network   GradientBoosting            0.050883
#                                 AdaBoost                    0.050883
#                                 DecisionTree                0.050883
#                                 ExtraTrees                  0.050883
#                                 LogisticRegression          0.050883
#                       regular   DecisionTree                0.050883
#                                 AdaBoost                    0.050883
#                                 ExtraTrees                  0.050883
#                       augmented LogisticRegression          0.050883
#                       regular   LogisticRegression          0.050883
#     firearm_outcome   augmented AdaBoost                    0.002827
#                                 Bagging                     0.002827
#                                 ExtraTrees                  0.002827
#                                 GradientBoosting            0.002827
#                                 RandomForest                0.002827
#                       regular   RandomForest                0.002827
#                       augmented DecisionTree                0.002827
#                       regular   AdaBoost                    0.002827
#                                 Bagging                     0.002827
#                                 DecisionTree                0.002827
#                                 ExtraTrees                  0.002827
#                                 GradientBoosting            0.002827
#                       network   AdaBoost                    0.002827
#                                 Bagging                     0.002827
#                                 RandomForest                0.002827
#                                 DecisionTree                0.002827
#                                 ExtraTrees                  0.002827
#                                 GradientBoosting            0.002827
#                       regular   LogisticRegression          0.002827
#                       augmented LogisticRegression          0.002827
#                       network   LogisticRegression          0.002827
#
#                                                     precision_at_20  \
# set outcome           type      model
# 3   sustained_outcome augmented RandomForest               0.160000
#                                 Bagging                    0.156667
#                                 GradientBoosting           0.166667
#                       regular   Bagging                    0.153333
#                                 RandomForest               0.150000
#                                 GradientBoosting           0.126667
#                       augmented ExtraTrees                 0.140000
#                                 AdaBoost                   0.143333
#                       network   GradientBoosting           0.100000
#                       augmented DecisionTree               0.120000
#                       network   ExtraTrees                 0.090000
#                                 RandomForest               0.103333
#                                 AdaBoost                   0.100000
#                                 Bagging                    0.106667
#                       regular   ExtraTrees                 0.100000
#                       network   DecisionTree               0.096667
#                       regular   DecisionTree               0.106667
#                                 AdaBoost                   0.120000
#                       network   LogisticRegression         0.056667
#                       augmented LogisticRegression         0.056667
#                       regular   LogisticRegression         0.053333
#     firearm_outcome   augmented AdaBoost                   0.003333
#                                 Bagging                    0.003333
#                                 DecisionTree               0.003333
#                                 GradientBoosting           0.003333
#                                 RandomForest               0.003333
#                       network   DecisionTree               0.003333
#                                 GradientBoosting           0.003333
#                       regular   AdaBoost                   0.003333
#                                 Bagging                    0.003333
#                                 DecisionTree               0.003333
#                                 GradientBoosting           0.003333
#                                 RandomForest               0.003333
#                       augmented ExtraTrees                 0.003333
#                                 LogisticRegression         0.003333
#                       network   AdaBoost                   0.003333
#                                 Bagging                    0.000000
#                                 ExtraTrees                 0.003333
#                                 LogisticRegression         0.003333
#                                 RandomForest               0.003333
#                       regular   ExtraTrees                 0.003333
#                                 LogisticRegression         0.003333
# 2   sustained_outcome augmented Bagging                    0.184416
#                                 RandomForest               0.197403
#                       regular   Bagging                    0.158442
#                       augmented GradientBoosting           0.200000
#                       regular   RandomForest               0.168831
#                                 GradientBoosting           0.166234
#                       network   RandomForest               0.135065
#                       augmented DecisionTree               0.158442
#                                 ExtraTrees                 0.142857
#                       network   AdaBoost                   0.124675
#                                 GradientBoosting           0.127273
#                                 Bagging                    0.124675
#                                 DecisionTree               0.124675
#                                 ExtraTrees                 0.122078
#                       augmented AdaBoost                   0.155844
#                       regular   ExtraTrees                 0.148052
#                                 DecisionTree               0.124675
#                                 AdaBoost                   0.127273
#                       network   LogisticRegression         0.116883
#                       augmented LogisticRegression         0.080519
#                       regular   LogisticRegression         0.067532
#     firearm_outcome   augmented AdaBoost                   0.002597
#                                 Bagging                    0.002597
#                                 DecisionTree               0.002597
#                                 ExtraTrees                 0.002597
#                                 GradientBoosting           0.002597
#                                 RandomForest               0.002597
#                       network   DecisionTree               0.002597
#                                 ExtraTrees                 0.002597
#                                 GradientBoosting           0.002597
#                       regular   AdaBoost                   0.002597
#                                 Bagging                    0.002597
#                                 DecisionTree               0.002597
#                                 ExtraTrees                 0.002597
#                                 GradientBoosting           0.002597
#                                 RandomForest               0.002597
#                       augmented LogisticRegression         0.002597
#                       network   AdaBoost                   0.002597
#                                 Bagging                    0.000000
#                                 LogisticRegression         0.002597
#                                 RandomForest               0.002597
#                       regular   LogisticRegression         0.002597
# 1   sustained_outcome augmented RandomForest               0.181609
#                                 Bagging                    0.172414
#                       regular   RandomForest               0.167816
#                                 Bagging                    0.160920
#                       augmented GradientBoosting           0.160920
#                       regular   GradientBoosting           0.135632
#                       augmented AdaBoost                   0.149425
#                       network   RandomForest               0.126437
#                                 GradientBoosting           0.124138
#                       augmented DecisionTree               0.137931
#                       network   Bagging                    0.119540
#                                 ExtraTrees                 0.114943
#                                 AdaBoost                   0.114943
#                                 DecisionTree               0.114943
#                       regular   AdaBoost                   0.117241
#                       augmented ExtraTrees                 0.135632
#                       regular   ExtraTrees                 0.119540
#                                 DecisionTree               0.124138
#                       augmented LogisticRegression         0.101149
#                       network   LogisticRegression         0.108046
#                       regular   LogisticRegression         0.071264
#     firearm_outcome   augmented AdaBoost                   0.004598
#                                 Bagging                    0.004598
#                                 DecisionTree               0.004598
#                                 ExtraTrees                 0.004598
#                                 GradientBoosting           0.004598
#                                 RandomForest               0.004598
#                       regular   AdaBoost                   0.004598
#                                 Bagging                    0.004598
#                                 DecisionTree               0.004598
#                                 ExtraTrees                 0.004598
#                                 GradientBoosting           0.004598
#                                 RandomForest               0.004598
#                                 LogisticRegression         0.002299
#                       augmented LogisticRegression         0.002299
#                       network   AdaBoost                   0.000000
#                                 Bagging                    0.000000
#                                 DecisionTree               0.000000
#                                 ExtraTrees                 0.000000
#                                 GradientBoosting           0.000000
#                                 LogisticRegression         0.000000
#                                 RandomForest               0.000000
# 0   sustained_outcome augmented RandomForest               0.164311
#                                 GradientBoosting           0.141343
#                       regular   RandomForest               0.146643
#                       augmented Bagging                    0.159011
#                       regular   Bagging                    0.148410
#                       augmented ExtraTrees                 0.132509
#                       regular   GradientBoosting           0.121908
#                       augmented DecisionTree               0.127208
#                       network   Bagging                    0.093640
#                                 RandomForest               0.100707
#                       augmented AdaBoost                   0.127208
#                       network   GradientBoosting           0.100707
#                                 AdaBoost                   0.098940
#                                 DecisionTree               0.098940
#                                 ExtraTrees                 0.100707
#                                 LogisticRegression         0.090106
#                       regular   DecisionTree               0.116608
#                                 AdaBoost                   0.121908
#                                 ExtraTrees                 0.125442
#                       augmented LogisticRegression         0.111307
#                       regular   LogisticRegression         0.058304
#     firearm_outcome   augmented AdaBoost                   0.012367
#                                 Bagging                    0.010601
#                                 ExtraTrees                 0.010601
#                                 GradientBoosting           0.012367
#                                 RandomForest               0.012367
#                       regular   RandomForest               0.012367
#                       augmented DecisionTree               0.010601
# ...
#                       augmented LogisticRegression 2011-12-31 11:38:24
#                       network   LogisticRegression 2011-12-31 11:38:24
#                       regular   LogisticRegression 2011-12-31 11:38:24
#     firearm_outcome   augmented AdaBoost           2011-12-31 11:38:24
#                                 Bagging            2011-12-31 11:38:24
#                                 DecisionTree       2011-12-31 11:38:24
#                                 ExtraTrees         2011-12-31 11:38:24
#                                 GradientBoosting   2011-12-31 11:38:24
#                                 RandomForest       2011-12-31 11:38:24
#                       regular   AdaBoost           2011-12-31 11:38:24
#                                 Bagging            2011-12-31 11:38:24
#                                 DecisionTree       2011-12-31 11:38:24
#                                 ExtraTrees         2011-12-31 11:38:24
#                                 GradientBoosting   2011-12-31 11:38:24
#                                 RandomForest       2011-12-31 11:38:24
#                                 LogisticRegression 2011-12-31 11:38:24
#                       augmented LogisticRegression 2011-12-31 11:38:24
#                       network   AdaBoost           2011-12-31 11:38:24
#                                 Bagging            2011-12-31 11:38:24
#                                 DecisionTree       2011-12-31 11:38:24
#                                 ExtraTrees         2011-12-31 11:38:24
#                                 GradientBoosting   2011-12-31 11:38:24
#                                 LogisticRegression 2011-12-31 11:38:24
#                                 RandomForest       2011-12-31 11:38:24
# 0   sustained_outcome augmented RandomForest       2010-12-31 05:49:12
#                                 GradientBoosting   2010-12-31 05:49:12
#                       regular   RandomForest       2010-12-31 05:49:12
#                       augmented Bagging            2010-12-31 05:49:12
#                       regular   Bagging            2010-12-31 05:49:12
#                       augmented ExtraTrees         2010-12-31 05:49:12
#                       regular   GradientBoosting   2010-12-31 05:49:12
#                       augmented DecisionTree       2010-12-31 05:49:12
#                       network   Bagging            2010-12-31 05:49:12
#                                 RandomForest       2010-12-31 05:49:12
#                       augmented AdaBoost           2010-12-31 05:49:12
#                       network   GradientBoosting   2010-12-31 05:49:12
#                                 AdaBoost           2010-12-31 05:49:12
#                                 DecisionTree       2010-12-31 05:49:12
#                                 ExtraTrees         2010-12-31 05:49:12
#                                 LogisticRegression 2010-12-31 05:49:12
#                       regular   DecisionTree       2010-12-31 05:49:12
#                                 AdaBoost           2010-12-31 05:49:12
#                                 ExtraTrees         2010-12-31 05:49:12
#                       augmented LogisticRegression 2010-12-31 05:49:12
#                       regular   LogisticRegression 2010-12-31 05:49:12
#     firearm_outcome   augmented AdaBoost           2010-12-31 05:49:12
#                                 Bagging            2010-12-31 05:49:12
#                                 ExtraTrees         2010-12-31 05:49:12
#                                 GradientBoosting   2010-12-31 05:49:12
#                                 RandomForest       2010-12-31 05:49:12
#                       regular   RandomForest       2010-12-31 05:49:12
#                       augmented DecisionTree       2010-12-31 05:49:12
#                       regular   AdaBoost           2010-12-31 05:49:12
#                                 Bagging            2010-12-31 05:49:12
#                                 DecisionTree       2010-12-31 05:49:12
#                                 ExtraTrees         2010-12-31 05:49:12
#                                 GradientBoosting   2010-12-31 05:49:12
#                       network   AdaBoost           2010-12-31 05:49:12
#                                 Bagging            2010-12-31 05:49:12
#                                 RandomForest       2010-12-31 05:49:12
#                                 DecisionTree       2010-12-31 05:49:12
#                                 ExtraTrees         2010-12-31 05:49:12
#                                 GradientBoosting   2010-12-31 05:49:12
#                       regular   LogisticRegression 2010-12-31 05:49:12
#                       augmented LogisticRegression 2010-12-31 05:49:12
#                       network   LogisticRegression 2010-12-31 05:49:12
#
#                                                    train_start
# set outcome           type      model
# 3   sustained_outcome augmented RandomForest        2010-01-01
#                                 Bagging             2010-01-01
#                                 GradientBoosting    2010-01-01
#                       regular   Bagging             2010-01-01
#                                 RandomForest        2010-01-01
#                                 GradientBoosting    2010-01-01
#                       augmented ExtraTrees          2010-01-01
#                                 AdaBoost            2010-01-01
#                       network   GradientBoosting    2010-01-01
#                       augmented DecisionTree        2010-01-01
#                       network   ExtraTrees          2010-01-01
#                                 RandomForest        2010-01-01
#                                 AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                       regular   ExtraTrees          2010-01-01
#                       network   DecisionTree        2010-01-01
#                       regular   DecisionTree        2010-01-01
#                                 AdaBoost            2010-01-01
#                       network   LogisticRegression  2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       regular   LogisticRegression  2010-01-01
#     firearm_outcome   augmented AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       network   DecisionTree        2010-01-01
#                                 GradientBoosting    2010-01-01
#                       regular   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       augmented ExtraTrees          2010-01-01
#                                 LogisticRegression  2010-01-01
#                       network   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 LogisticRegression  2010-01-01
#                                 RandomForest        2010-01-01
#                       regular   ExtraTrees          2010-01-01
#                                 LogisticRegression  2010-01-01
# 2   sustained_outcome augmented Bagging             2010-01-01
#                                 RandomForest        2010-01-01
#                       regular   Bagging             2010-01-01
#                       augmented GradientBoosting    2010-01-01
#                       regular   RandomForest        2010-01-01
#                                 GradientBoosting    2010-01-01
#                       network   RandomForest        2010-01-01
#                       augmented DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                       network   AdaBoost            2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                       augmented AdaBoost            2010-01-01
#                       regular   ExtraTrees          2010-01-01
#                                 DecisionTree        2010-01-01
#                                 AdaBoost            2010-01-01
#                       network   LogisticRegression  2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       regular   LogisticRegression  2010-01-01
#     firearm_outcome   augmented AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       network   DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                       regular   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       network   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 LogisticRegression  2010-01-01
#                                 RandomForest        2010-01-01
#                       regular   LogisticRegression  2010-01-01
# 1   sustained_outcome augmented RandomForest        2010-01-01
#                                 Bagging             2010-01-01
#                       regular   RandomForest        2010-01-01
#                                 Bagging             2010-01-01
#                       augmented GradientBoosting    2010-01-01
#                       regular   GradientBoosting    2010-01-01
#                       augmented AdaBoost            2010-01-01
#                       network   RandomForest        2010-01-01
#                                 GradientBoosting    2010-01-01
#                       augmented DecisionTree        2010-01-01
#                       network   Bagging             2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 AdaBoost            2010-01-01
#                                 DecisionTree        2010-01-01
#                       regular   AdaBoost            2010-01-01
#                       augmented ExtraTrees          2010-01-01
#                       regular   ExtraTrees          2010-01-01
#                                 DecisionTree        2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       network   LogisticRegression  2010-01-01
#                       regular   LogisticRegression  2010-01-01
#     firearm_outcome   augmented AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       regular   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                                 LogisticRegression  2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       network   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 LogisticRegression  2010-01-01
#                                 RandomForest        2010-01-01
# 0   sustained_outcome augmented RandomForest        2010-01-01
#                                 GradientBoosting    2010-01-01
#                       regular   RandomForest        2010-01-01
#                       augmented Bagging             2010-01-01
#                       regular   Bagging             2010-01-01
#                       augmented ExtraTrees          2010-01-01
#                       regular   GradientBoosting    2010-01-01
#                       augmented DecisionTree        2010-01-01
#                       network   Bagging             2010-01-01
#                                 RandomForest        2010-01-01
#                       augmented AdaBoost            2010-01-01
#                       network   GradientBoosting    2010-01-01
#                                 AdaBoost            2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 LogisticRegression  2010-01-01
#                       regular   DecisionTree        2010-01-01
#                                 AdaBoost            2010-01-01
#                                 ExtraTrees          2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       regular   LogisticRegression  2010-01-01
#     firearm_outcome   augmented AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                                 RandomForest        2010-01-01
#                       regular   RandomForest        2010-01-01
#                       augmented DecisionTree        2010-01-01
#                       regular   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                       network   AdaBoost            2010-01-01
#                                 Bagging             2010-01-01
#                                 RandomForest        2010-01-01
#                                 DecisionTree        2010-01-01
#                                 ExtraTrees          2010-01-01
#                                 GradientBoosting    2010-01-01
#                       regular   LogisticRegression  2010-01-01
#                       augmented LogisticRegression  2010-01-01
#                       network   LogisticRegression  2010-01-01

# %%
h = res_df2[['set', 'outcome','model', 'type','precision_at_5']]
h = h.sort_values(['set', 'type', 'precision_at_5'], ascending=False)
c_table = h.groupby(['set', 'type','outcome']).head(1)
pd.pivot_table(c_table,
# Out:
#      set            outcome             model       type  precision_at_5
# 4596   3  sustained_outcome           Bagging    regular        0.466667
# 3583   3    firearm_outcome      RandomForest    regular        0.013333
# 4420   3  sustained_outcome  GradientBoosting    network        0.280000
# 4091   3    firearm_outcome      DecisionTree    network        0.013333
# 3890   3  sustained_outcome      RandomForest  augmented        0.533333
# 3549   3    firearm_outcome      RandomForest  augmented        0.013333
# 3426   2  sustained_outcome           Bagging    regular        0.468750
# 2341   2    firearm_outcome      RandomForest    regular        0.010417
# 2698   2  sustained_outcome      RandomForest    network        0.354167
# 2777   2    firearm_outcome        ExtraTrees    network        0.010417
# 2714   2  sustained_outcome      RandomForest  augmented        0.562500
# 2349   2    firearm_outcome      RandomForest  augmented        0.010417
# 1542   1  sustained_outcome      RandomForest    regular        0.462963
# 1171   1    firearm_outcome      RandomForest    regular        0.018519
# 1318   1  sustained_outcome      RandomForest    network        0.314815
# 1175   1    firearm_outcome      RandomForest    network        0.000000
# 1550   1  sustained_outcome      RandomForest  augmented        0.518519
# 1185   1    firearm_outcome      RandomForest  augmented        0.018519
# 378    0  sustained_outcome      RandomForest    regular        0.432624
# 73     0    firearm_outcome      RandomForest    regular        0.042553
# 4      0  sustained_outcome      RandomForest    network        0.304965
# 89     0    firearm_outcome      RandomForest    network        0.021277
# 374    0  sustained_outcome      RandomForest  augmented        0.453901
# 87     0    firearm_outcome      RandomForest  augmented        0.042553

# %%
# plot stuff
sustained_df = res_df2[(res_df2.outcome == 'sustained_outcome') & (res_df2.type == 'augmented')].sort_values(['set', 'precision_at_5', 'model'], ascending=False)
sns.catplot(x='set', y='precision_at_5', hue='model', data=sustained_df, kind='swarm')
plt.title('Precision for sustained outcome, augmented models')
plt.ylabel('Precision at 5%')
plt.xlabel('Train-Test Set')

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        if point['val'] == 63:
            ax.text(point['x']+.02, point['y'], str(point['val']))

label_point(sustained_df.set, sustained_df.precision_at_5, sustained_df.param_set, plt.gca())

# %%
#filter top models
m = res_df2[res_df2.outcome == 'sustained_outcome'].sort_values(['set', 'precision_at_5'], ascending=False)
n = m[['set', 'model', 'param_set', 'parameters', 'type', 'precision_at_5', 'outcome']]

# %%
top_models = n.groupby('set').head(5).reset_index(drop=True)
top_models
# Out:
#    set         model param_set  \
# 0    3  RandomForest        63
# 1    3  RandomForest        15
# 2    3  RandomForest        27
# 3    3  RandomForest        51
# 4    3       Bagging         3
# 5    2  RandomForest        62
# 6    2  RandomForest        63
# 7    2       Bagging         4
# 8    2  RandomForest        27
# 9    2       Bagging         5
# 10   1  RandomForest        63
# 11   1       Bagging         4
# 12   1       Bagging         5
# 13   1  RandomForest        25
# 14   1  RandomForest        62
# 15   0  RandomForest        62
# 16   0  RandomForest        26
# 17   0  RandomForest        27
# 18   0  RandomForest        61
# 19   0  RandomForest        63
#
#                                            parameters       type  \
# 0   {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 1   {'criterion': 'gini', 'max_depth': 20, 'min_sa...  augmented
# 2   {'criterion': 'gini', 'max_depth': None, 'min_...  augmented
# 3   {'criterion': 'entropy', 'max_depth': 20, 'min...  augmented
# 4   {'bootstrap': True, 'max_samples': 1.0, 'n_est...  augmented
# 5   {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 6   {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 7   {'bootstrap': True, 'max_samples': 1.0, 'n_est...  augmented
# 8   {'criterion': 'gini', 'max_depth': None, 'min_...  augmented
# 9   {'bootstrap': True, 'max_samples': 1.0, 'n_est...  augmented
# 10  {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 11  {'bootstrap': True, 'max_samples': 1.0, 'n_est...  augmented
# 12  {'bootstrap': True, 'max_samples': 1.0, 'n_est...  augmented
# 13  {'criterion': 'gini', 'max_depth': None, 'min_...  augmented
# 14  {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 15  {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 16  {'criterion': 'gini', 'max_depth': None, 'min_...  augmented
# 17  {'criterion': 'gini', 'max_depth': None, 'min_...  augmented
# 18  {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
# 19  {'criterion': 'entropy', 'max_depth': None, 'm...  augmented
#
#     precision_at_5            outcome
# 0         0.533333  sustained_outcome
# 1         0.520000  sustained_outcome
# 2         0.520000  sustained_outcome
# 3         0.520000  sustained_outcome
# 4         0.520000  sustained_outcome
# 5         0.562500  sustained_outcome
# 6         0.562500  sustained_outcome
# 7         0.562500  sustained_outcome
# 8         0.552083  sustained_outcome
# 9         0.552083  sustained_outcome
# 10        0.518519  sustained_outcome
# 11        0.509259  sustained_outcome
# 12        0.509259  sustained_outcome
# 13        0.500000  sustained_outcome
# 14        0.500000  sustained_outcome
# 15        0.453901  sustained_outcome
# 16        0.446809  sustained_outcome
# 17        0.439716  sustained_outcome
# 18        0.439716  sustained_outcome
# 19        0.439716  sustained_outcome

# %%
for model in top_models.iterrows():
    print(model[1][0], model[1][1], model[1][2])
# Out:
# 3 RandomForest {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 3 RandomForest {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 3 RandomForest {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 2 RandomForest {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}
# 2 RandomForest {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 2 Bagging {'bootstrap': True, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}
# 1 RandomForest {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 1 Bagging {'bootstrap': True, 'max_samples': 1.0, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}
# 1 Bagging {'bootstrap': True, 'max_samples': 1.0, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
# 0 RandomForest {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}
# 0 RandomForest {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50, 'n_jobs': -1, 'random_state': 84}
# 0 RandomForest {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100, 'n_jobs': -1, 'random_state': 84}
